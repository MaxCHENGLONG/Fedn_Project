# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

def plot_label_distribution(labels, title='Label Distribution'):
    """
    统计并可视化标签的数量及占比。

    参数：
    labels (torch.Tensor 或 np.array): 标签数据。
    title (str): 可视化图表的标题。
    """
    # 将标签转换为 NumPy 数组
    labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else np.array(labels)

    # 使用 NumPy 统计每个标签的数量
    unique_labels, counts = np.unique(labels_np, return_counts=True)

    # 打印每个标签的数量及其占比
    total_count = len(labels_np)
    for label, count in zip(unique_labels, counts):
        percentage = (count / total_count) * 100
        print(f"Label: {label}, Count: {count}, Percentage: {percentage:.2f}%")

    # 可视化标签的数量
    plt.bar(unique_labels, counts)
    plt.xlabel('Labels')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(unique_labels)
    plt.show()

# 示例用法
data = torch.load('/Users/max/FEDN_LOCAL/2clients_50rounds_balanced_IID(Alpha=10)/clients_data/mnist1.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/3653699430.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clients_50rounds_balanced_IID(Alpha=10)/clients_data/mnist2.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/1487016555.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/mnist1.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 3, Count: 6131, Percentage: 26.01%
# Label: 6, Count: 5918, Percentage: 25.10%
# Label: 7, Count: 6264, Percentage: 26.57%
# Label: 9, Count: 5260, Percentage: 22.31%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/mnist2.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 5923, Percentage: 16.26%
# Label: 1, Count: 6742, Percentage: 18.51%
# Label: 2, Count: 5958, Percentage: 16.36%
# Label: 4, Count: 5841, Percentage: 16.04%
# Label: 5, Count: 5421, Percentage: 14.88%
# Label: 8, Count: 5851, Percentage: 16.06%
# Label: 9, Count: 688, Percentage: 1.89%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clietns_50rounds_imbalanced(10_01)_IID(Alpha=10)/clietns_data/mnist1.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/393766764.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clietns_50rounds_imbalanced(10_01)_IID(Alpha=10)/clietns_data/mnist2.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/713782853.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clients_50rounds_imbanlanced(1001)_Non_IID(Alpha=001)/clients_data/mnist1.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/3702077827.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/2clients_50rounds_imbanlanced(1001)_Non_IID(Alpha=001)/clients_data/mnist2.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 1, Count: 692, Percentage: 28.37%
# Label: 2, Count: 571, Percentage: 23.41%
# Label: 4, Count: 600, Percentage: 24.60%
# Label: 8, Count: 576, Percentage: 23.62%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/1/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/1570600532.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/2/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 2, Count: 5957, Percentage: 33.55%
# Label: 8, Count: 5850, Percentage: 32.95%
# Label: 9, Count: 5948, Percentage: 33.50%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/3/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 2, Percentage: 100.00%
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/2567841936.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/4/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 5879, Percentage: 47.56%
# Label: 1, Count: 217, Percentage: 1.76%
# Label: 7, Count: 6264, Percentage: 50.68%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_balanced_Non_IID(Alpha=001)/clients_data/5/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 5, Count: 5420, Percentage: 100.00%
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/758985277.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_im(10_08_03_01_01)_IID(Alpha=10)/clients_data/1/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 1007, Percentage: 8.22%
# Label: 1, Count: 1437, Percentage: 11.73%
# Label: 2, Count: 929, Percentage: 7.59%
# Label: 3, Count: 2054, Percentage: 16.77%
# Label: 4, Count: 719, Percentage: 5.87%
# Label: 5, Count: 803, Percentage: 6.56%
# Label: 6, Count: 1180, Percentage: 9.64%
# Label: 7, Count: 1601, Percentage: 13.07%
# Label: 8, Count: 1322, Percentage: 10.79%
# Label: 9, Count: 1195, Percentage: 9.76%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_50rounds_im(10_08_03_01_01)_IID(Alpha=10)/clients_data/2/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count:

# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5/clients_data/2/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 19, Percentage: 0.12%
# Label: 4, Count: 5841, Percentage: 37.47%
# Label: 7, Count: 6264, Percentage: 40.18%
# Label: 8, Count: 2747, Percentage: 17.62%
# Label: 9, Count: 719, Percentage: 4.61%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5/clients_data/3/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 6, Count: 24, Percentage: 0.46%
# Label: 9, Count: 5229, Percentage: 99.54%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5/clients_data/4/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 8, Count: 3103, Percentage: 100.00%
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/2002362227.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5/clients_data/5/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 5, Count: 5420, Percentage: 100.00%
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/3862087030.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_balanced_Alpha=10/clients_data/1/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# /var/folders/hr/2t7hsj753qg3n1q7zbnr625m0000gn/T/ipykernel_66301/650195419.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_balanced_Alpha=10/clients_data/2/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 873, Percentage: 7.71%
# Label: 1, Count: 1272, Percentage: 11.23%
# Label: 2, Count: 1251, Percentage: 11.04%
# Label: 3, Count: 1596, Percentage: 14.09%
# Label: 4, Count: 1258, Percentage: 11.10%
# Label: 5, Count: 956, Percentage: 8.44%
# Label: 6, Count: 668, Percentage: 5.90%
# Label: 7, Count: 1214, Percentage: 10.71%
# Label: 8, Count: 781, Percentage: 6.89%
# Label: 9, Count: 1461, Percentage: 12.89%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_balanced_Alpha=10/clients_data/3/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 889, Percentage: 6.52%
# Label: 1, Count: 1507, Percentage: 11.06%
# Label: 2, Count: 1312, Percentage: 9.63%
# Label: 3, Count: 1768, Percentage: 12.98%
# Label: 4, Count: 1196, Percentage: 8.78%
# Label: 5, Count: 1896, Percentage: 13.92%
# Label: 6, Count: 1218, Percentage: 8.94%
# Label: 7, Count: 1452, Percentage: 10.66%
# Label: 8, Count: 1100, Percentage: 8.07%
# Label: 9, Count: 1287, Percentage: 9.45%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_balanced_Alpha=10/clients_data/4/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 2042, Percentage: 15.71%
# Label: 1, Count: 923, Percentage: 7.10%
# Label: 2, Count: 1000, Percentage: 7.69%
# Label: 3, Count: 1131, Percentage: 8.70%
# Label: 4, Count: 995, Percentage: 7.65%
# Label: 5, Count: 1198, Percentage: 9.21%
# Label: 6, Count: 1594, Percentage: 12.26%
# Label: 7, Count: 1863, Percentage: 14.33%
# Label: 8, Count: 1114, Percentage: 8.57%
# Label: 9, Count: 1142, Percentage: 8.78%
# ...

# %%
data = torch.load('/Users/max/FEDN_LOCAL/5clients_balanced_Alpha=10/clients_data/5/mnist.pt')
y_train = data['y_train']
plot_label_distribution(y_train, title='Label Distribution in Training Set (y_train)')
# Out:
# Label: 0, Count: 1416, Percentage: 12.12%
# Label: 1, Count: 1211, Percentage: 10.37%
# Label: 2, Count: 1354, Percentage: 11.59%
# Label: 3, Count: 877, Percentage: 7.51%
# Label: 4, Count: 1451, Percentage: 12.42%
# Label: 5, Count: 574, Percentage: 4.91%
# Label: 6, Count: 1871, Percentage: 16.02%
# Label: 7, Count: 738, Percentage: 6.32%
# Label: 8, Count: 1592, Percentage: 13.63%
# Label: 9, Count: 597, Percentage: 5.11%
# ...

# %%
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
# 定义文件路径
file_paths = [
    "/Users/max/Fedn_Project/5clients_balanced_Alpha=10/metadata_1_10.0.json",
    "/Users/max/Fedn_Project/5clients_balanced_Alpha=10/metadata_2_10.0.json",
    "/Users/max/Fedn_Project/5clients_balanced_Alpha=10/metadata_3_10.0.json",
    "/Users/max/Fedn_Project/5clients_balanced_Alpha=10/metadata_4_10.0.json",
    "/Users/max/Fedn_Project/5clients_balanced_Alpha=10/metadata_5_10.0.json"
]

# 从文件中读取 local_path_norm 值
local_path_norms = []

with open(file_paths[0], 'r') as file:
    data = json.load(file)
    local_path_norms = [entry['local_path_norm'] for entry in data]

# 绘制折线图
plt.plot(local_path_norms, marker='o', linestyle='-', color='b')
plt.xlabel('Iteration')
plt.ylabel('Local Path Norm')
plt.title('Local Path Norm Over Iterations')
plt.grid(True)
plt.show()

# %%
# 从文件中读取 local_path_norm 值
local_path_norms = []

with open(file_paths[1], 'r') as file:
    data = json.load(file)
    local_path_norms = [entry['local_path_norm'] for entry in data]

# 绘制折线图
plt.plot(local_path_norms, marker='o', linestyle='-', color='b')
plt.xlabel('Iteration')
plt.ylabel('Local Path Norm')
plt.title('Local Path Norm Over Iterations')
plt.grid(True)
plt.show()

# %%
# 从文件中读取 local_path_norm 值
local_path_norms = []

with open(file_paths[2], 'r') as file:
    data = json.load(file)
    local_path_norms = [entry['local_path_norm'] for entry in data]

# 绘制折线图
plt.plot(local_path_norms, marker='o', linestyle='-', color='b')
plt.xlabel('Iteration')
plt.ylabel('Local Path Norm')
plt.title('Local Path Norm Over Iterations')
plt.grid(True)
plt.show()

# %%
# 从文件中读取 local_path_norm 值
local_path_norms = []

with open(file_paths[3], 'r') as file:
    data = json.load(file)
    local_path_norms = [entry['local_path_norm'] for entry in data]

# 绘制折线图
plt.plot(local_path_norms, marker='o', linestyle='-', color='b')
plt.xlabel('Iteration')
plt.ylabel('Local Path Norm')
plt.title('Local Path Norm Over Iterations')
plt.grid(True)
plt.show()

# %%
# 从文件中读取 local_path_norm 值
local_path_norms = []

with open(file_paths[4], 'r') as file:
    data = json.load(file)
    local_path_norms = [entry['local_path_norm'] for entry in data]

# 绘制折线图
plt.plot(local_path_norms, marker='o', linestyle='-', color='b')
plt.xlabel('Iteration')
plt.ylabel('Local Path Norm')
plt.title('Local Path Norm Over Iterations')
plt.grid(True)
plt.show()

# %%
local_path_norms
# Out:
# [6.157067685115655,
#  6.3467706713983505,
#  6.580730945952738,
#  6.832872952870526,
#  7.074765450192108,
#  7.297730095565983,
#  7.483823751962593,
#  7.660901583409013,
#  7.825663592686153,
#  7.978795201458757,
#  8.127281514202409,
#  8.260801238207343,
#  8.389892546155473,
#  8.519210760427917,
#  8.633598354008026,
#  8.742977266884424,
#  8.84732565693765,
#  8.952467969183571,
#  9.044219844611046,
#  9.140310428781786,
#  9.231914779911047,
#  9.322401786239794,
#  9.409559206393155,
#  9.496521865188894,
#  9.577200267764692,
#  9.658040988591045,
#  9.738337266059311,
#  9.810393672280789,
#  9.885278109245037,
#  9.955479701165698,
#  10.031021448306584,
#  10.094993963442883,
#  10.159954440097334,
#  10.22591510585714,
#  10.286741141121583,
#  10.347863984029864,
#  10.410262791873894,
#  10.467902305785609,
#  10.526907820867578,
#  10.584188822214577,
#  10.638053056659555,
#  10.69405578853851,
#  10.74591989490976,
#  10.799103480675056,
# ...
